# %% [markdown]
# # Abstract
# With this project I had the opportunity to explore web-scraping and text analysis. The aim of this notebook is to scrape some reviews for a product in a e-shop and then do a sentiment analysis and outliers detection

# %% [markdown]
# ## Obtaining the data

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %% [markdown]
# Scraping the reviews

# %%
def get_page(url):
  '''
  This function returns the site corresponding to the 
  url passed and in case of fail return -1
  '''
  page = requests.get(url)
  if page.status_code == 200:
    return page
  return -1

# %%
def get_urls(verbose = False):
  '''
  This function returns the list of all the pages of reviews for a product
  '''
  urls = []

  i=1
  url = 'https://www.ebay.com/urw/Bose-Soundbar-500-TV-Speaker-Black-838309-1100-/product-reviews/21040313446?_itm=195988019859&condition=all&pgn=1'
  response = get_page(url)
  soup = BeautifulSoup(response.text)

  #If this element is present we passed the last review page
  while soup.find('div', {'class' : 'empty-review-section'}) == None: 
    urls.append(url)
    i = i + 1

    #Next page
    url = url[:137] + str(i)
    response = get_page(url)
    soup = BeautifulSoup(response.text)

    if (verbose) and (i%5 == 0):
      print(f"I'm at page {i}")

  print(f'No. of pages: {len(urls)}')
  return urls

# %%
urls = get_urls(verbose = True)
# Out:
# I'm at page 5
# I'm at page 10
# I'm at page 15
# I'm at page 20
# No. of pages: 21

# %%
def get_ds(urls):
  '''
  From each comment in a page we extract :
  -Username
  -Title
  -Review
  -Stars
  -Condition
  -Date
  All this features create a row of the dataset
  '''
  
  ds = pd.DataFrame(columns = ['User','Title', 'Review', 'Score', 'Condition', 'Date'])

  months = {'Jan' : 1, 'Feb' : 2, 'Mar' : 3, 'Apr' : 4, 'May' : 5, 'Jun' : 6, 'Jul' : 7, 'Aug' : 8, 'Sep' : 9, 'Oct' : 10, 'Nov' : 11, 'Dec' : 12}

  for url in urls:
    response = get_page(url)
    soup = BeautifulSoup(response.text)

    for current_div in soup.find_all('div', {'class':'ebay-review-section'}):
      #Each <div> contains all the feature of the reviews
      
      #User
      user = current_div.find('a', {'class' : 'review-item-author'}).text
      #Title
      title =  current_div.find('h3').text
      #Review-body: if not present = NA
      if current_div.find('p', {'class':'review-item-content rvw-wrap-spaces'}) != None:
        review = current_div.find('p', {'class':'review-item-content rvw-wrap-spaces'}).text.replace('\n', '')
      else:
        review = pd.NA
      #Number of stars
      stars = float(current_div.find('span', {'class' : 'star-rating'}).attrs["aria-label"][0])
      #Condition: if not present = NA
      if current_div.find('span', {'class' : 'rvw-val capitalize'}) != None:
        condition = current_div.find('span', {'class' : 'rvw-val capitalize'}).text
      else:
        condition = pd.NA
      #Date: date phasing
      date_split = current_div.find('span', {'class' : 'review-item-date'}).text.replace(',', '').split(' ')
      date_split[0] = str(months[date_split[0]])
      date = '-'.join(date_split)

      ds.loc[len(ds)] = {'User':user, 'Title':title, 'Review':review, 'Score':stars, 'Condition':condition,'Date':date}

  ds['Date'] = pd.to_datetime(ds['Date'], format = '%m-%d-%Y')

  return ds

# %% [markdown]
# Creating the dataset

# %%
ds = get_ds(urls)
ds.head()
# Out:
#            User                                              Title
# 0       hm60261                Good but there are better options.   \
# 1  cochransk123                                        Not Special
# 2     swansonda                  Product Meets Advertised Quality
# 3      e-greg80  Broke 60 days after… He’s not authorized Bose ...
# 4    ghil_s2006                                Somewhat defective
#
#                                               Review  Score    Condition
# 0  This is an entry level Bose sound bar. It has ...    4.0          new  \
# 1  I purchased this speaker because of the Name r...    3.0  refurbished
# 2  Product provides excellent enhanced quality of...    5.0          new
# 3  I’ll start this buy saying this is a fantastic...    3.0          new
# 4  Not as immersive as I expected. Something not ...    2.0    pre-owned
#
#         Date
# 0 2021-12-21
# 1 2023-01-18
# 2 2020-12-08
# 3 2022-07-11
# 4 2023-06-25

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209 entries, 0 to 208
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   User       209 non-null    object
#  1   Title      209 non-null    object
#  2   Review     204 non-null    object
#  3   Score      209 non-null    float64
#  4   Condition  193 non-null    object
#  5   Date       209 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 11.4+ KB

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# Score histogram

# %%
ds['Score'].astype(int) \
    .value_counts().sort_index() \
    .plot(kind = 'bar',
          figsize = (10, 5),
          rot = 0,
          xlabel = 'Score',
          ylabel = 'Frequency',
          title = 'Score Histogram')
plt.show()

# %% [markdown]
# Score histogram for each condition

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (15, 5))

ds[ds['Condition'] == 'new']['Score'].value_counts().sort_index().plot(
    kind = 'bar',
    title = 'New items score',
    xlabel = 'Score',
    ylabel = 'Frequency',
    ax = ax[0]
)

ax[0].set_xticklabels([1, 2, 3, 4, 5], rotation = 0)
ax[0].set_ylim((0, 75))

ds[ds['Condition'] == 'refurbished']['Score'].value_counts().sort_index().plot(
    kind = 'bar',
    title = 'Refurbished items score',
    xlabel = 'Score',
    ylabel = 'Frequency',
    ax = ax[1]
)

ax[1].set_xticklabels([1, 2, 3, 4, 5], rotation = 0)
ax[1].set_ylim((0, 75))

ds[ds['Condition'] == 'pre-owned']['Score'].value_counts().sort_index().plot(
    kind = 'bar',
    title = 'Pre-owned items score',
    xlabel = 'Score',
    ylabel = 'Frequency',
    ax = ax[2]
)

ax[2].set_xticks([-1, 0, 1, 2, 3])
ax[2].set_xticklabels([1, 2, 3, 4, 5], rotation = 0)
ax[2].set_xlim((-1.5, 3.5))
ax[2].set_ylim((0, 75))

plt.show()

# %% [markdown]
# Time series of the mean score for each month

# %%
ds.groupby([ds['Date'].dt.year, ds['Date'].dt.month])['Score'].mean() \
  .plot(figsize = (15, 5),
        xlabel = 'Date',
        ylabel = 'Score',
        title = 'Score per Month')
plt.show()

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# Importing libraries

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jacop\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("Good music")
# Out:
# {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}

# %% [markdown]
# Adding the sentiment info at the dataset

# %%
sia = SentimentIntensityAnalyzer()
'''
Getting the polarity_score (Negative, Neutral, Positive and Compound)
for each review if the review is not NA, 
and then adding it to a new column of the ds
'''
pol_scores = pd.DataFrame(columns = ["Negative", "Neutral", "Positive", "Compound"])

for review in ds['Review'].values:
  if pd.notna(review):
    pol = sia.polarity_scores(review)
    pol_scores.loc[len(pol_scores), ["Negative", "Neutral", "Positive", "Compound"]] = pol['neg'], pol['neu'], pol['pos'], pol['compound']
  else:
    pol_scores.loc[len(pol_scores), ["Negative", "Neutral", "Positive", "Compound"]] = pd.NA

ds = ds.join(pol_scores, how = 'left')

ds.head()
# Out:
#            User                                              Title
# 0       hm60261                Good but there are better options.   \
# 1  cochransk123                                        Not Special
# 2     swansonda                  Product Meets Advertised Quality
# 3      e-greg80  Broke 60 days after… He’s not authorized Bose ...
# 4    ghil_s2006                                Somewhat defective
#
#                                               Review  Score    Condition
# 0  This is an entry level Bose sound bar. It has ...    4.0          new  \
# 1  I purchased this speaker because of the Name r...    3.0  refurbished
# 2  Product provides excellent enhanced quality of...    5.0          new
# 3  I’ll start this buy saying this is a fantastic...    3.0          new
# 4  Not as immersive as I expected. Something not ...    2.0    pre-owned
#
#         Date Negative Neutral Positive Compound
# 0 2021-12-21      0.0   0.847    0.153   0.9419
# 1 2023-01-18    0.082   0.857    0.061   0.0772
# 2 2020-12-08      0.0   0.774    0.226   0.9349
# 3 2022-07-11    0.031   0.825    0.145   0.9964
# 4 2023-06-25    0.042   0.869    0.089   0.6915

# %% [markdown]
# Compound Distribution

# %%
ds[pd.notna(ds['Compound'])]['Compound'].astype('float') \
  .plot(kind = 'kde',
        # bins = 50,
        figsize = (10, 5),
        rot = 0,
        title = 'Compound Distribution')
plt.xlabel('Compound Score')
plt.show()

# %% [markdown]
# Comparison between mean score per month and compound score per month

# %%
fig,ax = plt.subplots()
ds.groupby([ds['Date'].dt.year, ds['Date'].dt.month])['Compound'].mean() \
  .plot(rot = 0,
        xlabel = 'Month',
        ylabel = 'Polarity Score',
        title = 'Polarity Score and Score per Month',
        ax = ax)
# plt.grid(visible=False)

ax2 = ax.twinx()
ds.groupby([ds['Date'].dt.year, ds['Date'].dt.month])['Score'].mean() \
  .plot(figsize = (15, 6),
        ylabel = 'Stars',
        color = 'blue',
        ax = ax2)
# plt.grid(visible=False)

# plt.tight_layout()
fig.legend(loc='upper right')
plt.show()

# %% [markdown]
# Correlation between the two scores

# %%
ds_mod = ds
ds_corr = ds_mod[['Score', 'Compound']].copy()
ds_corr = ds_corr.dropna()
ds_corr['Compound'] = ds_corr['Compound'].astype('float')

sns.heatmap(ds_corr.corr(), annot = True)
plt.show()

# %% [markdown]
# Outliers identification<br>
# <i>Outliers in this dataset are characterized by a neutral score of 1, this happens because some comments are not written in English and/or because the polarity score function gets the classification wrong<i>

# %%
ds[ds['Neutral'] == 1]
# Out:
#                   User                           Title
# 89          sgarner106  sounds ridiculously incredible  \
# 119           mrosel80                              👍👍
# 120            abeo_57                   Nice speaker
# 128            lam8kis        The Sound is real good!
# 131        rofranci_43      Bose - The name sums it up
# 132          renf_lydi      Great to understand voices
# 137  ddedde_llk94da1pc                    Bose quality
# 153             na9002                  very satisfied
# 154             mbalun                       Good size
# 164        omugh.omugh              Great and amazing
# 168           flier062                Economical Bose!
# 177          davi19470                 Excellent sound
# 180           krpsport                   Great speaker
# 181             gmaz11                  Great product
# 196    splergatwannies      Amazing sound, a must buy!
# 201             ja7001              뛰어난 기능을 갖추고 심플합니다.
# 204             405_sr             Era lo que esperaba
# 205        marcguaich0                      Excelente
#
#                                                                      Review
# 89                the closest you can get to a surround system in one piece  \
# 119       Grear sound for a small package and I got it at the right price 👌
# 120       I have a Bose speaker for my pc, and I knee we hat I was getting
# 128                                            Brought our new TV to life!
# 131   If you know Bose, you know there is always quality in their products.
# 132                   I can hear and understand what the people are saying.
# 137                          Small package with big sound a quality product
# 153                                                              Its a Bose
# 154                                                          As advertised
# 164                  It’s simply the best., couldn’t think of anything else
# 168                                Usual Bose quality at a reasonable cost!
# 177                        Home thaeter quality without being overpowering!
# 180  I have 1 con. It needs a lit up volume, and an on signal on the front.
# 181                                                                5 stars
# 196                                               " we need more cow bell!"
# 201                            심플하고 간결하게 설치 및 사용이 편하고 음량이나 음색 또한 기대 이상 입니다.
# 204                          Sonido de calidad, fácil de usar y elegante...
# 205                                                      Excelente Gracias
#
#      Score    Condition       Date Negative Neutral Positive Compound
# 89     5.0  refurbished 2021-08-17      0.0     1.0      0.0      0.0
# 119    5.0  refurbished 2021-05-17      0.0     1.0      0.0      0.0
# 120    4.0          new 2023-05-05      0.0     1.0      0.0      0.0
# 128    5.0  refurbished 2022-01-03      0.0     1.0      0.0      0.0
# 131    5.0          new 2022-06-11      0.0     1.0      0.0      0.0
# 132    5.0          new 2022-03-14      0.0     1.0      0.0      0.0
# 137    5.0    pre-owned 2021-10-19      0.0     1.0      0.0      0.0
# 153    5.0          new 2020-12-14      0.0     1.0      0.0      0.0
# 154    5.0  refurbished 2022-08-06      0.0     1.0      0.0      0.0
# 164    4.0          new 2021-03-31      0.0     1.0      0.0      0.0
# 168    5.0  refurbished 2021-08-09      0.0     1.0      0.0      0.0
# 177    5.0  refurbished 2021-11-16      0.0     1.0      0.0      0.0
# 180    5.0  refurbished 2021-08-30      0.0     1.0      0.0      0.0
# 181    5.0          new 2022-02-18      0.0     1.0      0.0      0.0
# 196    5.0          NaN 2020-10-29      0.0     1.0      0.0      0.0
# 201    5.0          new 2022-12-19      0.0     1.0      0.0      0.0
# 204    5.0          new 2021-07-13      0.0     1.0      0.0      0.0
# 205    5.0          new 2021-05-11      0.0     1.0      0.0      0.0

# %% [markdown]
# Correlation between the two scores <br>
# <i>this time without outliers<i>

# %%
ds_mod = ds[ds['Neutral'] != 1]
ds_corr = ds_mod[['Score', 'Compound']].copy()
ds_corr = ds_corr.dropna()
ds_corr['Compound'] = ds_corr['Compound'].astype('float')

sns.heatmap(ds_corr.corr(), annot = True)
plt.show()

# %%
ds.columns
# Out:
# Index(['User', 'Title', 'Review', 'Score', 'Condition', 'Date', 'Negative',
#        'Neutral', 'Positive', 'Compound'],
#       dtype='object')

# %% [markdown]
# Highest score reviews

# %%
# pd.set_option('display.max_colwidth', None)
ds.sort_values(by='Score', ascending=False)[['Review', 'Score', 'Negative', 'Neutral', 'Positive', 'Compound']].reset_index(drop=True).head(10)
# Out:
#                                                                          Review
# 0                                                      Great sound!... love it!  \
# 1  Excellent sound bar. Good value. Like new ... good warranty for refurbished.
# 2                                                                Just AMAZING!!
# 3                               Works very well, clear sound perfect for my TV.
# 4                                      Easy to setup. Good sound. Great price.
# 5                              I am enjoying using the Bose speaker sound bar.
# 6                                                  We love our new TV Soundbar!
# 7                      Excellent speaker,Bose rocks it..Excellent price also...
# 8                                                               Excellent sound
# 9                                       Sounds good but voices could be better.
#
#    Score Negative Neutral Positive Compound
# 0    5.0      0.0   0.184    0.816   0.8715
# 1    5.0      0.0   0.327    0.673   0.9246
# 2    5.0      0.0   0.163    0.837   0.7284
# 3    5.0      0.0   0.401    0.599    0.839
# 4    5.0      0.0   0.288    0.712    0.872
# 5    5.0      0.0   0.673    0.327   0.5267
# 6    5.0      0.0   0.527    0.473   0.6696
# 7    5.0      0.0   0.575    0.425   0.5719
# 8    5.0      0.0   0.213    0.787   0.5719
# 9    5.0      0.0   0.463    0.537   0.7003

# %%
ds.sort_values(by='Score', ascending=True)[['Review', 'Score', 'Negative', 'Neutral', 'Positive', 'Compound']].reset_index(drop=True).head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Review
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Annoying sound delay very evident at all dialog: live, movies and recorded video.  Followed simple instructions and recommended high quality short HDMI eARC cable direct from new 4K Samsung  43 inch TV.   Read full review...  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                I’ve had it for a week now and tried to get it to work with no success. I know Bose makes quality products but unfortunately this one missed the mark.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The speaker arrived very fast, and appeared to be new, although it was certified refurbished, and tested. The speaker would not turn on at all. I tested the power cable and it was good. I also tried other outletreceptacles, to no avail. Quality control dropped the ball, if the speaker was indeed tested.Read full review...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The machine gets scolding hot when plugged in. Sound quality is good but I’m afraid the machine will combust. Looking to return this item
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     I understand this is Bose's entry level speaker, but it's not worthy of the brand. Poor features, poor value and ordinary sound.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              After 3 days it will not turn on.remove &replace power cord 2 white lights blink for 30 secs,then nothing .The remote is fine,i have 2.Troubleshooting guide says it needs service at this pointThe one i bought prior to this one recently had garbled sound after 3 hrs use.TALK ABOUT BAD LUCK!!!!Read full review...
# 6  Avoid this one unless you only watch talk shows and like to repeatedly try to get things to work. .  We've used a Bose SoundLink mini for years for music and to get better sound from our TVs.  I thought this would be a worthwhile upgrade.  The instructions state to only connect one input type. We have a higher end LG tv 2020 model and connected via HDMI ARC.  Sometimes the TV remote can control the volume (as it should) many times it can not and we are forced to use the Bose remote.  Sometimes we get no sound from the Bose  even though the TV can "see" the Bose - it shows the Bose is connected to the input.  Bluetooth works for the  most part - We have an Amazon Echo streaming music to the bose.  The Bose easily connects every time but has frequent glitches in the music and especially drops if we walk between the Bose and the Echo broadcasting the music feed - the feed glitches.  The two units are approximately 15 ft apart.  We have tried moving the Echo closer - it did not improve the results.  We tried other bluetooth devices with similar results. We would use the aux in but the instructions state to only use one physical input and there is not feature for switching which input you are using other than "TV" or Bluetooth.  As the unit does not consistently work even with the HDMI input alone we did not try using the aux and HDMI and externally choosing which device is playing.  The music quality is not what I expect of Bose.  The sound has a lot more pronounced treble compared to the SoundLink mini thanks to the tweeter.  Overall the sound is too bright, harsh and lacking mids.  Bass is done well.  I thought maybe we accidentally had dialogue mode turned on all the time. The LED indicates dialogue mode does turn on/off and pressing the dialogue mode button does change the sound. We find in unenjoyable in all cases. Increasing the bass does tone down the highs but the bass is then very boomy.  With only one tweeter, there is no stereo imaging - we knew this would be the case going in and only mention it here in case you had not thought of that.. Pros: clear dialogueCons: doesn't always work as it should via HDMI ARC, Bluetooth cuts out frequently, music is too bright and missing midrange.  Even for the price of a refurb you can get a lot better sound from something else at the same price point.  Read full review...
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Horrible shipping time and bad sound.Bad purchase all around.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            The sound is not the good
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   I have a cheap vmai that sounds as good as this speaker. The treble sounds tinny to me, the bass is ok. I use to think bose was the best sound,but now not so sure.
#
#    Score Negative Neutral Positive Compound
# 0    1.0    0.129   0.825    0.046  -0.4939
# 1    1.0    0.222   0.709    0.069   -0.631
# 2    1.0    0.039   0.909    0.052   0.1779
# 3    1.0      0.0   0.922    0.078   0.2382
# 4    1.0    0.362    0.54    0.098  -0.8522
# 5    1.0    0.101   0.899      0.0  -0.7507
# 6    1.0    0.057   0.873     0.07   0.7132
# 7    1.0      0.5     0.5      0.0  -0.7906
# 8    1.0    0.325   0.675      0.0  -0.3412
# 9    2.0    0.062   0.704    0.234   0.7799

# %%
ds.sort_values(by='Positive', ascending=False)[['Review', 'Score', 'Negative', 'Neutral', 'Positive', 'Compound']].reset_index(drop=True).head(10)
# Out:
#                              Review  Score Negative Neutral Positive Compound
# 0                       Good value     4.0      0.0     0.0      1.0   0.6486
# 1                             Good     5.0      0.0     0.0      1.0   0.4404
# 2                             Good.    5.0      0.0     0.0      1.0   0.4404
# 3                  All OK 👌 thanks     5.0      0.0   0.146    0.854   0.7034
# 4                    Just AMAZING!!    5.0      0.0   0.163    0.837   0.7284
# 5          Great sound!... love it!    5.0      0.0   0.184    0.816   0.8715
# 6               Very happy love it     5.0      0.0   0.191    0.809   0.8581
# 7                  Awesome speaker     5.0      0.0   0.196    0.804   0.6249
# 8  Great purchase excellent quality    5.0      0.0   0.204    0.796   0.8316
# 9                     Amazing sound    5.0      0.0   0.208    0.792   0.5859

# %%
ds.sort_values(by='Negative', ascending=False)[['Review', 'Score', 'Negative', 'Neutral', 'Positive', 'Compound']].reset_index(drop=True).head(10)
# Out:
#                                                                                                                                                    Review
# 0                                                                                           Horrible shipping time and bad sound.Bad purchase all around.  \
# 1                                                                                                                   Instructions and paperwork very poor.
# 2                                                                                                                     very disappointed in this sound box
# 3                       I understand this is Bose's entry level speaker, but it's not worthy of the brand. Poor features, poor value and ordinary sound.
# 4                                                                                                                       Sound power is not strong enough.
# 5                                                                                                                              The sound is not the good
# 6                                                                                                                           No esperaba menos de un Bose.
# 7                                                                                                            The Audio OPTICAL  was broke on the speaker.
# 8                                                                                                                  Not much better then regular TV sound.
# 9  I’ve had it for a week now and tried to get it to work with no success. I know Bose makes quality products but unfortunately this one missed the mark.
#
#    Score Negative Neutral Positive Compound
# 0    1.0      0.5     0.5      0.0  -0.7906
# 1    3.0    0.459   0.541      0.0  -0.5256
# 2    3.0    0.404   0.596      0.0  -0.5256
# 3    1.0    0.362    0.54    0.098  -0.8522
# 4    5.0    0.351   0.649      0.0  -0.4023
# 5    1.0    0.325   0.675      0.0  -0.3412
# 6    4.0    0.306   0.694      0.0   -0.296
# 7    3.0    0.286   0.714      0.0  -0.4215
# 8    3.0    0.286   0.714      0.0  -0.3412
# 9    1.0    0.222   0.709    0.069   -0.631
